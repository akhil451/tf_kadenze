# %%
# os.system('conda install -c anaconda nb_conda')

# %%
import os

# %%
import tensorflow as tf

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x=tf.linspace(-3.0,3.0,100)

# %%
g=tf.get_default_graph()

# %%
[op.name for op in g.get_operations()]
# Out:
# ['LinSpace/start', 'LinSpace/stop', 'LinSpace/num', 'LinSpace']

# %%
sess=tf.InteractiveSession()

# %%
z=x.eval()

# %%
print(x.get_shape())
# Out:
# (100,)

# %%
plt.plot(z)

# %%
mean=0
sigma=1.0
gaus = (tf.exp(tf.negative(tf.pow(x-mean,2.0)/2.0*tf.pow(sigma,2.0))))*(1/sigma*tf.sqrt(2.0*3.141))

# %%
gaussian=gaus.eval()

# %%
ksize=gaussian.shape;
n=ksize[0];n
# Out:
# 100

# %%
gaussian.reshape(-1,1).T.shape
# Out:
# (1, 100)

# %%
plt.plot(gaus.eval())

# %%
gaus_2d = tf.matmul(gaussian.reshape(-1,1),gaussian.reshape(-1,1).T)

# %%
plt.imshow(gaus_2d.eval())
